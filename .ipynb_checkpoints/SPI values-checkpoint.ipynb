# %% [markdown]
# https://github.com/monocongo/climate_indices/issues/514#issuecomment-1563129915

# %% [markdown]
# https://www.drought.gov/data-maps-tools/global-gridded-standardized-precipitation-index-spi-cmorph-daily

# %% [markdown]
# https://github.com/monocongo/example_climate_indices/tree/master/example/input

# %%
import xarray as xr
import pandas as pd
import glob

# %%
files = glob.glob("*.nc")

# %%
files
# Out:
# ['CMORPH_V1.0_ADJ_0.25deg-DLY_00Z_19980101.nc']

# %%
ds = xr.open_dataset(files[0])

# %%
ds.isel(time=0).cmorph.plot()

# %% [markdown]
# https://github.com/monocongo/climate_indices/blob/master/notebooks/PDSI_Canadian_Stations.ipynb

# %%
import climate_indices

# %%
dir(climate_indices.indices)
# Out:
# ['Dict',
#  'Distribution',
#  'Enum',
#  '_FITTED_INDEX_VALID_MAX',
#  '_FITTED_INDEX_VALID_MIN',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__warningregistry__',
#  '_fit_altnames',
#  '_logger',
#  '_norm_fitdict',
#  'compute',
#  'eto',
#  'logging',
#  'np',
#  'numba',
#  'palmer',
#  'pci',
#  'pdsi',
#  'percentage_of_normal',
#  'pet',
#  'scpdsi',
#  'spei',
#  'spi',
#  'utils']

# %%
climate_indices.indices.spi()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 climate_indices.indices.spi()
#
# TypeError: not enough arguments: expected at least 7, got 0
